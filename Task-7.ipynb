# %% [markdown]
# <a href="https://colab.research.google.com/github/pavandheeraj27560/AIT/blob/main/Task-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
monkey="window"
box="window"
banana=False
print("Monkey walks to box")
print("Monkey pushes box under bananas")
box="under banana"
print("Monkey climbs box")
print("Monkey grasps banana")
banana=True
print("Goal achieved:",banana)
# Out:
# Monkey walks to box
# Monkey pushes box under bananas
# Monkey climbs box
# Monkey grasps banana
# Goal achieved: True
