# %% [markdown]
# <a href="https://colab.research.google.com/github/pavandheeraj27560/AIT/blob/main/Scenarios_Dfs%26Bfs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque
graph={
    "master":["E1","E2"],
    "E1":["E3","E4"],
    "E2":["E5"],
    "E3":[],
    "E4":[],
    "E5":[]
}
offline={"E4"}
visited=set()
queue=deque([("master",0)])
failed=[]
max_time=0
while queue:
  node,time=queue.popleft()
  if node in visited:
    continue
  visited.add(node)
  if node in offline:
    failed.append(node)
    continue
  print(f"{node} reached at {time}sec")
  max_time=max(max_time,time)
  for neighbor in graph[node]:
    if neighbor not in visited:
      queue.append((neighbor,time+1))
      print("Minimum Time:",max_time,"seconds")
      print("offline servers:",failed)
# Out:
# master reached at 0sec
# Minimum Time: 0 seconds
# offline servers: []
# Minimum Time: 0 seconds
# offline servers: []
# E1 reached at 1sec
# Minimum Time: 1 seconds
# offline servers: []
# Minimum Time: 1 seconds
# offline servers: []
# E2 reached at 1sec
# Minimum Time: 1 seconds
# offline servers: []
# E3 reached at 2sec
# E5 reached at 2sec

# %%
graph={
    'A':['B','C'],
    'B':['A','B','C'],
    'C':['A','F'],
    'D':['B'],
    'E':['B','F'],
    'F':['C','F','G'],
    'G':['F']
}
visited=set()
path=[]
def dfs(node):
  visited.add(node)
  path.append(node)
  print("visiting:",node)
  for neighbor in graph[node]:
    if neighbor not in visited:
      dfs(neighbor)
  print("Backtracking from:",node)

start='A'
dfs(start)
print("Exploration path:", "--".join(path))
print("visited chambers:",visited)
# Out:
# visiting: A
# visiting: B
# visiting: C
# visiting: F
# visiting: G
# Backtracking from: G
# Backtracking from: F
# Backtracking from: C
# Backtracking from: B
# Backtracking from: A
# Exploration path: A--B--C--F--G
# visited chambers: {'A', 'C', 'F', 'G', 'B'}
